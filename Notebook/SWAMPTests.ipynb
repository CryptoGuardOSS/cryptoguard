// %% [markdown]
// # Generated Test

// %% [markdown]
// ## Test javaParser_1_Java

// %%
            //Custom Imports
            List<String> addedJars = %jars *.jar
            %maven junit:junit:4.12

            //CryptoGuard imports
            import frontEnd.Interface.EntryPoint;
            import static org.junit.Assert.assertFalse;
            import static org.junit.Assert.assertTrue;
            import static org.junit.Assert.assertEquals;
            import static org.junit.Assert.assertNull;
            import static org.junit.Assert.assertNotNull;
            import static util.Utils.makeArg;

            import frontEnd.Interface.outputRouting.ExceptionHandler;
            import frontEnd.Interface.ArgumentsCheck;
            import frontEnd.MessagingSystem.routing.Listing;
            import frontEnd.MessagingSystem.routing.EnvironmentInformation;
            import frontEnd.MessagingSystem.routing.structure.Default.Report;
            import frontEnd.MessagingSystem.routing.structure.Scarf.AnalyzerReport;
            import frontEnd.MessagingSystem.routing.structure.Scarf.BugInstance;
            import frontEnd.argsIdentifier;
            import java.io.File;
            import java.nio.charset.StandardCharsets;
            import java.nio.file.Files;
            import java.nio.file.Paths;
            import java.util.ArrayList;
            import java.util.Arrays;
            import java.util.List;
            import org.junit.After;
            import org.junit.Before;
            import org.junit.Test;
            import org.junit.runner.RunWith;
            import rule.engine.EngineType;
            import soot.G;
            import util.Utils;

// %%
  //region String Statics

  public static final Boolean isLinux = !System.getProperty("os.name").contains("Windows");

  public static final String basePath = System.getProperty("user.dir");

  public static final String scarfArgs =

      Utils.osPathJoin(basePath, "src", "main", "resources", "Scarf", "sample.properties");

  public static final String testRec = Utils.osPathJoin(basePath, "samples");

  public static final String testPath = Utils.osPathJoin(basePath, "build", "tmp");

  public static final String testRec_tester_test = Utils.osPathJoin(testRec, "temp", "tester");

  public static final String testRec_tester_test_Class =

      Utils.osPathJoin(testRec_tester_test, "test.class");

  public static final String testRec_tester_test_Java =

      Utils.osPathJoin(testRec_tester_test, "test.java");

  public static final String testRec_tester_test_Java_xml =

      Utils.osPathJoin(testPath, "test_java.xml");

  public static final String srcOneGrv = Utils.osPathJoin(testRec, "testable-jar");



  public static final String pracitceJavaPackage =

      Utils.osPathJoin(srcOneGrv, "src", "main", "java", "tester", "Crypto_VeryTemp.java");



  public static final String verySimple_Gradle = Utils.osPathJoin(testRec, "VerySimple_Gradle");

  public static final String verySimple_Gradle_File =

      Utils.osPathJoin(verySimple_Gradle, "src", "main", "java", "very.java");



  public static final String crypto_Example = Utils.osPathJoin(testRec, "Crypto_Example");

  public static final String crypto_Example_File =

      Utils.osPathJoin(crypto_Example, "src", "main", "java", "Crypto.java");



  public static final String passwordUtils_Example =

      Utils.osPathJoin(testRec, "PasswordUtils_Example");

  public static final String passwordUtils_Example_File =

      Utils.osPathJoin(passwordUtils_Example, "src", "main", "java", "PasswordUtils.java");



  public static final String symCrypto_Example = Utils.osPathJoin(testRec, "SymCrypto_Example");

  public static final String symCrypto_Example_File =

      Utils.osPathJoin(symCrypto_Example, "src", "main", "java", "SymCrypto.java");



  public static final String symCrypto_Package_Example =

      Utils.osPathJoin(testRec, "SymCrypto_Package_Example");

  public static final String symCrypto_Example_Package_File =

      Utils.osPathJoin(

          symCrypto_Package_Example, "src", "main", "java", "tester", "SymCrypto.java");



  public static final String symCrypto_Multiple_Example =

      Utils.osPathJoin(testRec, "SymCrypto_Multi_Example");

  public static final String symCrypto_Multiple_Example_File_1 =

      Utils.osPathJoin(symCrypto_Multiple_Example, "src", "main", "java", "SymCrypto.java");

  public static final String symCrypto_Multiple_Example_File_2 =

      Utils.osPathJoin(symCrypto_Multiple_Example, "src", "main", "java", "PassEncryptor.java");



  public static final String srcOneGrv_base = "tester";

  public static final String srcOneGrvInputFile = Utils.osPathJoin(srcOneGrv, "input.in");

  public static final String javaSource =

      Utils.osPathJoin(srcOneGrv, "src", "main", "java", "tester");

  public static final String classSource =

      Utils.osPathJoin(srcOneGrv, "build", "classes", "java", "main", "tester");

  public static final String[] classFiles = {

    Utils.osPathJoin(classSource, "PBEUsage.class"),

    Utils.osPathJoin(classSource, "UrlFrameWorks.class"),

    Utils.osPathJoin(classSource, "NewTestCase1.class"),

    Utils.osPathJoin(classSource, "NewTestCase2.class")

  };

  public static final String newTestCaseTwo_Class =

      Utils.osPathJoin(classSource, "NewTestCase2.class");

  public static final String newTestCaseTwo_xml =

      Utils.osPathJoin(testPath, "NewTestCase2-class.xml");

  public static final String newTestCaseTwo_xml_0 =

      Utils.osPathJoin(testPath, "NewTestCase2-class_0.xml");

  public static final String testablejar_Crypto_plugin_class_json =

      Utils.osPathJoin(testPath, "java-plugin-file_One.json");

  public static final String testablejar_Crypto_plugin_class_json_0 =

      Utils.osPathJoin(testPath, "java-plugin-file_One_0.json");

  public static final String testablejar_PBEUsage_class_xml =

      Utils.osPathJoin(testPath, "PBEUsage-class-file_One.xml");

  public static final String testablejar_Crypto_class =

      Utils.osPathJoin(classSource, "Crypto.class");

  public static final String testablejar_Crypto_class_xml =

      Utils.osPathJoin(testPath, "java-file_One.xml");

  public static final String testablejar_Crypto_class_xml_0 =

      Utils.osPathJoin(testPath, "java-file_One_0.xml");

  public static final String[] javaFiles = {

    Utils.osPathJoin(javaSource, "PBEUsage.java"),

    Utils.osPathJoin(javaSource, "UrlFrameWorks.java")

  };

  public static final String jarOne =

      Utils.osPathJoin(testRec, "testable-jar", "build", "libs", "testable-jar.jar");

  public static final String srcOneGrvDep =

      Utils.osPathJoin(testRec, "testable-jar", "build", "dependencies");

  public static final String javaFileOne = Utils.osPathJoin(testPath, "java-file_One.xml");

  public static final String javaFileTwo = Utils.osPathJoin(testPath, "java-file_Two.txt");

  public static final String javaFileThree = Utils.osPathJoin(testPath, "java-file_Three.txt");

  public static final String javaFileThreeXML = Utils.osPathJoin(testPath, "java-file_Three.xml");

  public static final String pathToSchema =

      Utils.osPathJoin(basePath, "src", "main", "resources", "Scarf", "scarf_v1.2.xsd");

  public static final String pathToAPK = Utils.osPathJoin(testRec, "app-debug.apk");

  public static final String tempFileOutTxt = Utils.osPathJoin(testPath, "testable-jar.txt");

  public static final String tempFileOutXML = Utils.osPathJoin(testPath, "testable-jar.xml");

  public static final String tempFileOutJSON = Utils.osPathJoin(testPath, "testable-jar.json");

  public static final String tempTestJJava_Txt = Utils.osPathJoin(testPath, "temp_java-jar.txt");

  public static final String tempStreamXML = Utils.osPathJoin(testPath, "testable-jar_Stream.xml");

  public static final String tempFileOutTxt_two =

      Utils.osPathJoin(testPath, "testable-jar_classFiles.txt");

  public static final String tempFileOutTxt_two_0 =

      Utils.osPathJoin(testPath, "testable-jar_classFiles_0.txt");

  public static final String tempFileOutTxt_default =

      Utils.osPathJoin(testPath, "testable-jar_classFiles.json");

  public static final String tempFileOutTxt_default_0 =

      Utils.osPathJoin(testPath, "testable-jar_classFiles_0.json");

  public static final String tempFileOutXML_two =

      Utils.osPathJoin(testPath, "testable-jar_classFiles.xml");

  public static final String tempFileOutTxt_Class =

      Utils.osPathJoin(testPath, "java-class-file.txt");

  public static final String tempFileOutTxt_Class_fullproj =

      Utils.osPathJoin(testPath, "java-class-proj-file.xml");

  public static final String tempFileOutTxt_Class_fullproj_0 =

      Utils.osPathJoin(testPath, "java-class-proj-file_0.xml");

  public static final String tempFileOutTxt_Class_tester_test =

      Utils.osPathJoin(testPath, "java-class-file_sample_tester-test.txt");

  public static final String tempFileOutXML_Class_0 =

      Utils.osPathJoin(testPath, "java-class-file_0.xml");

  public static final String tempFileOutXML_Class_1 =

      Utils.osPathJoin(testPath, "java-class-file_1.xml");

  public static final String tempFileOutXML_Class_Stream_0 =

      Utils.osPathJoin(testPath, "java-class-file-stream_0.xml");

  public static final String tempFileOutApk = Utils.osPathJoin(testPath, "app-debug.txt");

  public static final String tempFileOutApk_CSV = Utils.osPathJoin(testPath, "app-debug.csv");

  public static final String tempFileOutApk_Steam =

      Utils.osPathJoin(testPath, "app-debug_Stream.txt");

  public static final String tempFileOutApk_CSVStream =

      Utils.osPathJoin(testPath, "app-debug_Stream.csv");

  public static final String tempFileOutApk_YAMLStream =

      Utils.osPathJoin(testPath, "app-debug_Stream.yaml");

  public static final String tempFileOutApk_Scarf = Utils.osPathJoin(testPath, "app-debug.xml");

  public static final String tempFileOutApk_Scarf_XArgs =

      Utils.osPathJoin(testPath, "app-debug_XArgs.xml");

  public static final String tempFileOutApk_Scarf_Steam =

      Utils.osPathJoin(testPath, "app-debug_Stream.xml");

  public static final String tempFileOutApk_Default = Utils.osPathJoin(testPath, "app-debug.json");

  public static final String tempFileOutApk_Default_Steam =

      Utils.osPathJoin(testPath, "app-debug_Stream.json");



  public static final String tempFileOutJson_Project =

      Utils.osPathJoin(testPath, "very-simple_Project.json");

  public static final String crypto_Example_Json_Project =

      Utils.osPathJoin(testPath, "Crypto_Example_Project.json");

  public static final String passwordUtils_Example_Json_Project =

      Utils.osPathJoin(testPath, "PasswordUtils_Example_Project.json");

  public static final String symCrypto_Example_Json_Project =

      Utils.osPathJoin(testPath, "SymCrypto_Example_Project.json");



  public static final String tempFileOutJson_File =

      Utils.osPathJoin(testPath, "very-simple_File.json");

  public static final String crypto_Example_Json_File =

      Utils.osPathJoin(testPath, "Crypto_Example_File.json");

  public static final String passwordUtils_Example_Json_File =

      Utils.osPathJoin(testPath, "PasswordUtils_Example_File.json");

  public static final String symCrypto_Example_Json_File =

      Utils.osPathJoin(testPath, "SymCrypto_Example_File.json");

  public static final String symCrypto_Example_Package_Json_File =

      Utils.osPathJoin(testPath, "SymCrypto_Package_Example_File.json");

  public static final String symCrypto_Multiple_Files =

      Utils.osPathJoin(testPath, "SymCrypto_Example_Files.json");



  public static final String tempJarFile_txt = Utils.osPathJoin(testPath, "tempJarFile_txt.txt");

  public static final String tempJarFile_Scarf_0 =

      Utils.osPathJoin(testPath, "tempJarFile_Scarf_0.xml");

  public static final String tempJarFile_Scarf_1 =

      Utils.osPathJoin(testPath, "tempJarFile_Scarf_1.xml");

  public static final String tempJarFile_Scarf_2 =

      Utils.osPathJoin(testPath, "tempJarFile_Scarf_2.xml");

  public static final String tempJarFile_Scarf_Steam_1 =

      Utils.osPathJoin(testPath, "tempJarFile_Scarf_Steam_1.xml");

  public static final String tempJarFile_Default_0 =

      Utils.osPathJoin(testPath, "tempJarFile_Default_0.json");

  public static final String tempJarFile_Default_Stream_0 =

      Utils.osPathJoin(testPath, "tempJarFile_Default_Stream_0.json");

  public static final ArrayList<String> sampleAuxClassPathOneList =

      new ArrayList<>(

          Arrays.asList(testRec, jarOne, javaFiles[0], javaFiles[1], classFiles[0], classFiles[1]));

  public static final String sampleAuxClassPathOne = String.join(":", sampleAuxClassPathOneList);

  public static final ArrayList<String> sampleAuxClassPathTwoList =

      new ArrayList<>(

          Arrays.asList(

              testRec,

              jarOne,

              javaFiles[0],

              javaFiles[1],

              classFiles[0],

              classFiles[1],

              scarfArgs));

  public static final String sampleAuxClassPathTwo = String.join(":", sampleAuxClassPathTwoList);

  public static final String verySimple_Path = Utils.osPathJoin(testRec, "VerySimple");

  public static final String verySimple_Jar = Utils.osPathJoin(verySimple_Path, "very.jar");

  public static final String verySimple_Jar_xml = Utils.osPathJoin(testPath, "verySimple_jar.xml");

  public static final String verySimple_Java = Utils.osPathJoin(verySimple_Path, "very.java");

  public static final String verySimple_Java_xml =

      Utils.osPathJoin(testPath, "verySimple_java.xml");

  public static final String verySimple_Klass = Utils.osPathJoin(verySimple_Path, "very.class");

  public static final String verySimple_Klass_xml =

      Utils.osPathJoin(testPath, "verySimple_klass.xml");

  public static final String verySimple_Klass_xml_0 =

      Utils.osPathJoin(testPath, "verySimple_klass_0.xml");

  public static final String verySimple_Klass_xml_1 =

      Utils.osPathJoin(testPath, "verySimple_klass_1.xml");

  public static final String verySimple_Klass_csv_1 =

      Utils.osPathJoin(testPath, "verySimple_klass_1.csv");

  public static final String verySimple_Klass_xml_2 =

      Utils.osPathJoin(testPath, "verySimple_klass_2.xml");

  public static final String verySimple_Klass_yaml_1 =

      Utils.osPathJoin(testPath, "verySimple_klass_2.yaml");

  public static final ArrayList<String> srcOneGrvInputArr =

      new ArrayList<>(

          Arrays.asList(

              Utils.osPathJoin(javaSource, "UrlFrameWorks.java"),

              Utils.osPathJoin(javaSource, "PasswordUtils.java"),

              Utils.osPathJoin(javaSource, "Crypto.java"),

              Utils.osPathJoin(javaSource, "PBEUsage.java"),

              Utils.osPathJoin(javaSource, "NewTestCase2.java"),

              Utils.osPathJoin(javaSource, "VeryBusyClass.java"),

              Utils.osPathJoin(javaSource, "SymCrypto.java"),

              Utils.osPathJoin(javaSource, "NewTestCase1.java"),

              Utils.osPathJoin(javaSource, "LiveVarsClass.java"),

              Utils.osPathJoin(javaSource, "PassEncryptor.java")));

  public static final ArrayList<String> srcOneGrvInputArr_Class =

      new ArrayList<>(

          Arrays.asList(

              Utils.osPathJoin(classSource, "UrlFrameWorks.class"),

              Utils.osPathJoin(classSource, "PasswordUtils.class"),

              Utils.osPathJoin(classSource, "Crypto.class"),

              Utils.osPathJoin(classSource, "Crypto$1.class"),

              Utils.osPathJoin(classSource, "Crypto$2.class"),

              Utils.osPathJoin(classSource, "Crypto$3.class"),

              Utils.osPathJoin(classSource, "PBEUsage.class"),

              Utils.osPathJoin(classSource, "NewTestCase2.class"),

              Utils.osPathJoin(classSource, "VeryBusyClass.class"),

              Utils.osPathJoin(classSource, "SymCrypto.class"),

              Utils.osPathJoin(classSource, "NewTestCase1.class"),

              Utils.osPathJoin(classSource, "LiveVarsClass.class"),

              Utils.osPathJoin(classSource, "PassEncryptor.class")));

  //endregion



  public static String[] cleaningArgs(String arg) {

    ArrayList<String> cleanArgs = new ArrayList<>(Arrays.asList(arg.split(" ")));

    cleanArgs.removeIf(StringUtils::isEmpty);

    return cleanArgs.toArray(new String[cleanArgs.size()]);

  }



  public static String captureNewFileOutViaStdOut(String[] args, Boolean exceptionHandler) {

    //region Redirecting the std out to capture the file out

    //The new std out

    ByteArrayOutputStream baos = new ByteArrayOutputStream();

    PrintStream ps = new PrintStream(baos);



    //Old out

    PrintStream old = System.out;



    //Redirecting the std out to the capture

    System.setOut(ps);



    //region Critical Section

    EntryPoint.main(args);

    //endregion



    //Resetting the std out

    System.out.flush();

    System.setOut(old);

    //endregion



    //The output string

    String outputString = StringUtils.trimToNull(baos.toString());

    if (!exceptionHandler) assertTrue(StringUtils.isNotBlank(outputString));



    String[] lines = baos.toString().split(Utils.lineSep);

    outputString = StringUtils.trimToNull(lines[lines.length - 1]);

    if (!exceptionHandler) assertTrue(StringUtils.isNotBlank(outputString));



    return outputString;

  }



  public static String captureNewFileOutViaStdOut(String[] args) throws Exception {



    return captureNewFileOutViaStdOut(args, false);

  }



  public static String[] arr(ArrayList<String> in) {

    return in.toArray(new String[in.size()]);

  }



  public static ArrayList<String> arr(String[] in) {

    return new ArrayList<>(Arrays.asList(in));

  }



  public static String getFileNameFromString(String filePath) {

    if (StringUtils.isBlank(filePath)) return "";



    filePath = StringUtils.trimToNull(filePath);

    String[] splits = filePath.split(Utils.fileSep);

    String fileName = splits[splits.length - 1];



    return StringUtils.trimToNull(fileName.substring(0, fileName.indexOf(".")));

  }



  public static String retrieveFilesFromDir(String dir, String name) {



    ProcessBuilder cmd = new ProcessBuilder();



    cmd.command(("find " + dir + " -name " + name).split(" "));



    StringBuilder output = new StringBuilder();



    try {

      Process exe = cmd.start();

      String line;



      try (BufferedReader reader =

          new BufferedReader(new InputStreamReader(exe.getInputStream()))) {

        while ((line = reader.readLine()) != null) {

          output.append(line).append("\n");

        }

      } catch (Exception e) {



      }



    } catch (Exception e) {



    }

    return output.toString();

  }



  public static InputStream setIn(String string) {

    InputStream input = System.in;

    System.setIn(new ByteArrayInputStream(string.getBytes()));

    return input;

  }

// %%
            //Utililties

            String java_home = "/home/runner/.sdkman/candidates/java/8.0.252-zulu";
            Boolean isLinux = true;

            public static String captureNewFileOutViaStdOut(String[] args, Boolean exceptionHandler) {
            //region Redirecting the std out to capture the file out
            //The new std out
            ByteArrayOutputStream baos = new ByteArrayOutputStream();
            PrintStream ps = new PrintStream(baos);

            //Old out
            PrintStream old = System.out;

            //Redirecting the std out to the capture
            System.setOut(ps);

            //region Critical Section
            EntryPoint.main(args);
            //endregion

            //Resetting the std out
            System.out.flush();
            System.setOut(old);
            //endregion

            //The output string
            String outputString = StringUtils.trimToNull(baos.toString());
            if (!exceptionHandler) assertTrue(StringUtils.isNotBlank(outputString));
            String[] lines = baos.toString().split(Utils.lineSep);
            outputString = StringUtils.trimToNull(lines[lines.length - 1]);
            if (!exceptionHandler) assertTrue(StringUtils.isNotBlank(outputString));

            return outputString;
            }

            public static String captureNewFileOutViaStdOut(String[] args) throws Exception {

                return captureNewFileOutViaStdOut(args, false);
            }
            public static String[] arr(ArrayList<String> in) {
                return in.toArray(new String[in.size()]);
            }

            public static ArrayList<String> arr(String[] in) {
                return new ArrayList<>(Arrays.asList(in));
            }

// %%
   public void javaParser_1_Java() { 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 BASEPATH + "/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/resolution/types/ResolvedPrimitiveTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/SlowTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue84.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/ConstructorsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/JavaParserFacadeResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/ExprResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/StatementContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/InternalClassInInterfaceTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnonymousClassesResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/MethodLikeSignaturesTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/MethodsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/SymbolSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/MethodsResolutionLogicTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnalyseJavaSymbolSolver060Test.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/LambdaResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/DefaultPackageTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/UnknownMethodsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnalyseNewJavaParserHelpersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnalyseJavaParserTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AbstractResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/EnumLiteralsInAnnotatedClassTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/ArrayExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/SymbolSolverWithJavassistClassTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/reflectionmodel/SymbolResolutionResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/QualifiedNameResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/SymbolSolverWithJavassistEnumTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/SubtypeOfBoundTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/SameAsBoundTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/ConstraintFormulaTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/SymbolSolverWithJavassistInterfaceTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/EnumResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/FieldsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/MethodCallExprContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/ClassOrInterfaceDeclarationContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/CompilationUnitContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/FieldAccessContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/MethodContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/EnumDeclarationContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/contexts/LambdaExprContextResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/VarTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/javaparser/declarations/JavaParserTypeParameterResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typesolvers/ReflectionTypeSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typesolvers/JavaParserTypeSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typesolvers/AarTypeSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/typesolvers/JarTypeSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/ContextTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnalyseNewJavaParserTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/GenericsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/naming/NameLogicDisambiguationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/naming/AbstractNameLogicTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/naming/NameLogicTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/naming/NameLogicTestingJss060Test.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/AnnotationsResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/resolution/VariadicResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistClassDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistInterfaceDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistParameterDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javassistmodel/Issue257.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistEnumDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/SolveMethodDeclaredInEnumTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue228.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1814.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue314.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/JavaParserAPIIntegrationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue232.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/NullTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/ArrayTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/WildcardUsageTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/VoidTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/ReferenceTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/PrimitiveTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/model/typesystem/TypeVariableUsageTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue200.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue251.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/testingclasses/SomeClass.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/testingclasses/UtilityClass.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1491.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1364.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1668.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionEnumDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionClassDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionMethodDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionParameterDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionInterfaceDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue144.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/AbstractSymbolResolutionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1485.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue241.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue18.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/utils/SymbolSolverCollectionStrategyTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/utils/LeanParserConfiguration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue156.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue185.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/MultiCatchMethodCallExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/ConvertToUsageTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserAnonymousClassDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserInterfaceDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserEnumDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserClassDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/javaparsermodel/DifferentiateDotExpressionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue1946.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue347.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue276.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/FindingAllFields.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue128.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/logic/InferenceContextTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/logic/FunctionInterfaceLogicTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue186.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue235.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue343.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/JavaSymbolSolverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue116.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue300.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue113.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  //SOMEWHERE
String cur_user = System.getProperty("user.name");
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/target/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/target/classes"); 
                 add("/home/maister/.m2/repository/junit/junit/4.12/junit-4.12.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/hamcrest/hamcrest-core/1.3/hamcrest-core-1.3.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/target/javaparser-symbol-solver-logic-3.8.1.jar"); 
                 add( 
                     "/home/"+cur_user+"/.m2/repository/org/javassist/javassist/3.24.0-GA/javassist-3.24.0-GA.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/guava/27.0-jre/guava-27.0-jre.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/failureaccess/1.0/failureaccess-1.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/checkerframework/checker-qual/2.5.2/checker-qual-2.5.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/errorprone/error_prone_annotations/2.2.0/error_prone_annotations-2.2.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/j2objc/j2objc-annotations/1.1/j2objc-annotations-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/codehaus/mojo/animal-sniffer-annotations/1.17/animal-sniffer-annotations-1.17.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mockito/mockito-core/2.23.0/mockito-core-2.23.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/net/bytebuddy/byte-buddy/1.9.0/byte-buddy-1.9.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/net/bytebuddy/byte-buddy-agent/1.9.0/byte-buddy-agent-1.9.0.jar"); 
                 add("/home/maister/.m2/repository/org/objenesis/objenesis/2.6/objenesis-2.6.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/target/javaparser-symbol-solver-model-3.8.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/target/javaparser-symbol-solver-core-3.8.1.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.VERYVERBOSE) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_1_Java()
// Out:
// |      public void javaParser_1_Java() {
// |
// |        ArrayList<String> tempSource =
// |            new ArrayList<String>() {
// |              {
// |                add(
// |                    "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/resolution/types/ResolvedPrimitiveTypeTest.java");
// |                add(
// |                    "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/SlowTest.java");
// |                add(
// |                    "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-testing/src/test/java/com/github/javaparser/symbolsolver/Issue84.java");
// |                add(
// ...

// %%
public void javaParser_2_Java() { 
     String fileOut = "_javaParser_2.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/MethodResolutionLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/ConstructorResolutionLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/SymbolSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ConstraintFormulaSet.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/FalseBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/SubtypeOfBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/ThrowsBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/SameAsBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/bounds/CapturesBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/Substitution.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/TypeInferenceCache.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/TypeHelper.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/InferenceVariableSubstitution.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/BoundSet.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ProperUpperBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ConstraintFormula.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ExpressionHelper.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/InferenceVariable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/InstantiationSet.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ControlFlowLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/ProperLowerBound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/Bound.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/Instantiation.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/MethodType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/TypeCompatibleWithType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/ExpressionCompatibleWithType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/TypeSubtypeOfType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/TypeContainedByType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/TypeSameAsType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/LambdaThrowsCompatibleWithType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/constraintformulas/MethodReferenceThrowsCompatibleWithType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typeinference/TypeInference.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/SymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/JarTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/MemoryTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/AarTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/CombinedTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/ReflectionTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/ClassLoaderTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/typesolvers/JavaParserTypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/naming/NameCategory.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/naming/NameLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/resolution/naming/NameRole.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistAnnotationDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistTypeParameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistEnumConstantDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistFieldDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistAnnotationMemberDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/package-info.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistTypeDeclarationAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistParameterDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistEnumDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistInterfaceDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistMethodDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javassistmodel/JavassistFactory.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/core/resolution/Context.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/core/resolution/MethodUsageResolutionCapability.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/core/resolution/ContextHelper.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/model/typesystem/ReferenceTypeImpl.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/model/typesystem/LazyType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/JavaSymbolSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/comparators/MethodComparator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/comparators/ClassComparator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/comparators/ParameterComparator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionAnnotationMemberDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionFactory.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionEnumConstantDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/MyObjectProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionTypeParameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/package-info.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionMethodResolutionLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionClassAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionAnnotationDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionMethodDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionInterfaceDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionParameterDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionEnumDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/reflectionmodel/ReflectionFieldDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/utils/SymbolSolverCollectionStrategy.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarators/NoSymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarators/ParameterSymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarators/AbstractSymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarators/FieldSymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarators/VariableSymbolDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/LambdaArgumentTypePlaceholder.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ConstructorContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/TryWithResourceContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/AnonymousClassDeclarationContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ObjectCreationContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/MethodCallExprContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/AbstractMethodLikeDeclarationContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/FieldAccessContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ContextHelper.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/EnumDeclarationContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ForEachStatementContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/VariableDeclaratorContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ClassOrInterfaceDeclarationContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/CompilationUnitContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/AbstractJavaParserContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/VariableDeclarationExprContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/CatchClauseContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/LambdaExprContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/JavaParserTypeDeclarationAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/StatementContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/MethodContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/ForStatementContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/SwitchEntryContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/contexts/BlockStmtContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/JavaParserFacade.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/package-info.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/UnsolvedSymbolException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/DefaultVisitorAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/TypeExtractor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/JavaParserFactory.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/AstResolutionUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserTypeParameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserTypeVariableDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserMethodDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserTypeAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserAnonymousClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserAnnotationMemberDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/DefaultConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserSymbolDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserEnumDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserFieldDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserAnnotationDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserVariableDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserInterfaceDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserEnumConstantDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserParameterDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparsermodel/declarations/JavaParserConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/SourceFileInfoExtractor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparser/Navigator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/javaparser/package-info.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/src/main/java/com/github/javaparser/symbolsolver/declarations/common/MethodDeclarationCommonLogic.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-core/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/target/javaparser-symbol-solver-logic-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/javassist/javassist/3.24.0-GA/javassist-3.24.0-GA.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/target/javaparser-symbol-solver-model-3.8.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/guava/27.0-jre/guava-27.0-jre.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/failureaccess/1.0/failureaccess-1.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/checkerframework/checker-qual/2.5.2/checker-qual-2.5.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/errorprone/error_prone_annotations/2.2.0/error_prone_annotations-2.2.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/j2objc/j2objc-annotations/1.1/j2objc-annotations-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/codehaus/mojo/animal-sniffer-annotations/1.17/animal-sniffer-annotations-1.17.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_2_Java()

// %%
public void javaParser_3_Java() { 
     String fileOut = "_javaParser_3.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/AbstractClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/InferenceVariableType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/MethodResolutionCapability.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/ObjectProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/InferenceContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/ConfilictingGenericTypesException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/AbstractTypeDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/src/main/java/com/github/javaparser/symbolsolver/logic/FunctionalInterfaceLogic.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-logic/target/classes"); 
                 add( 
                     "/home/maister/.m2/repository/org/javassist/javassist/3.24.0-GA/javassist-3.24.0-GA.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/target/javaparser-symbol-solver-model-3.8.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/guava/27.0-jre/guava-27.0-jre.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/failureaccess/1.0/failureaccess-1.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/checkerframework/checker-qual/2.5.2/checker-qual-2.5.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/errorprone/error_prone_annotations/2.2.0/error_prone_annotations-2.2.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/j2objc/j2objc-annotations/1.1/j2objc-annotations-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/codehaus/mojo/animal-sniffer-annotations/1.17/animal-sniffer-annotations-1.17.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_3_Java()

// %%
public void javaParser_4_Java() { 
     String fileOut = "_javaParser_4.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/src/main/java/com/github/javaparser/symbolsolver/model/resolution/Value.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/src/main/java/com/github/javaparser/symbolsolver/model/resolution/SymbolReference.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/src/main/java/com/github/javaparser/symbolsolver/model/resolution/TypeSolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/src/main/java/com/github/javaparser/symbolsolver/model/typesystem/NullType.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-symbol-solver-model/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/javassist/javassist/3.24.0-GA/javassist-3.24.0-GA.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/guava/27.0-jre/guava-27.0-jre.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/failureaccess/1.0/failureaccess-1.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/checkerframework/checker-qual/2.5.2/checker-qual-2.5.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/errorprone/error_prone_annotations/2.2.0/error_prone_annotations-2.2.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/google/j2objc/j2objc-annotations/1.1/j2objc-annotations-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/codehaus/mojo/animal-sniffer-annotations/1.17/animal-sniffer-annotations-1.17.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_4_Java()

// %%
public void javaParser_5_Java() { 
     String fileOut = "_javaParser_5.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/src/test/java/com/github/javaparser/serialization/JavaParserJsonSerializerTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/src/test/java/com/github/javaparser/serialization/JavaParserJsonDeserializerTest.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/target/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/target/classes"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-engine/5.3.1/junit-jupiter-engine-5.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apiguardian/apiguardian-api/1.0.0/apiguardian-api-1.0.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-engine/1.3.1/junit-platform-engine-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-commons/1.3.1/junit-platform-commons-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/opentest4j/opentest4j/1.1.1/opentest4j-1.1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-api/5.3.1/junit-jupiter-api-5.3.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/"user"/.m2/repository/javax/json/javax.json-api/1.1.4/javax.json-api-1.1.4.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/glassfish/javax.json/1.1.4/javax.json-1.1.4.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         //OLD
		   //String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
		 //NEW
		   EntryPoint.main(args.split(" "));
		 String outputFile = fileOut;
		   
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_5_Java()

// %%
public void javaParser_5_Java_Two() { 
     String fileOut = "_javaParser_5.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/src/test/java/com/github/javaparser/serialization/JavaParserJsonSerializerTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/src/test/java/com/github/javaparser/serialization/JavaParserJsonDeserializerTest.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/target/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-serialization/target/classes"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-engine/5.3.1/junit-jupiter-engine-5.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apiguardian/apiguardian-api/1.0.0/apiguardian-api-1.0.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-engine/1.3.1/junit-platform-engine-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-commons/1.3.1/junit-platform-commons-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/opentest4j/opentest4j/1.1.1/opentest4j-1.1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-api/5.3.1/junit-jupiter-api-5.3.1.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/javax/json/javax.json-api/1.1.4/javax.json-api-1.1.4.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/glassfish/javax.json/1.1.4/javax.json-1.1.4.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_5_Java_Two()

// %%
public void javaParser_7_Java() { 
     String fileOut = "javaParser_7.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/MetaModelGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/InitializePropertyMetaModelsStatementsGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/AstTypeAnalysis.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/InitializeConstructorParametersStatementsGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/NodeMetaModelGenerator.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_7_Java()

// %%
public void javaParser_7_Java_Two() { 
     String fileOut = "javaParser_7.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 BASEPATH+"/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/MetaModelGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/InitializePropertyMetaModelsStatementsGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/AstTypeAnalysis.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/InitializeConstructorParametersStatementsGenerator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/src/main/java/com/github/javaparser/generator/metamodel/NodeMetaModelGenerator.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-metamodel-generator/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_7_Java_Two()

// %%
public void javaParser_9_Java() { 
     String fileOut = "_javaParser_9.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/metamodel/BaseNodeMetaModelTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/metamodel/PropertyMetaModelTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ProblemTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/RangeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/stmt/IfElseStmtTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/stmt/TryStmtTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/stmt/BlockStmtTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java5ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java11ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java1_3ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java7ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java6ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java12ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java1_4ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java8ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java1_2ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java9ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java10ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java1_0ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/validator/Java1_1ValidatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/NodeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/comments/CommentTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/NodeListTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/ReplaceNodeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/DataKeyTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/NameTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/AssignExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/LiteralStringValueExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/SimpleNameTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/CharLiteralExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/MethodCallExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/StringLiteralExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/DoubleLiteralExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/MethodReferenceExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/ThisExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/SuperExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/LambdaExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/InstanceOfExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/expr/BinaryExprTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/type/TypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/type/ArrayTypeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/body/MethodDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/body/AnnotationMemberDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/body/ClassOrInterfaceDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/body/ConstructorDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/body/FieldDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/ParseResultTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/NoCommentHashCodeVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/NoCommentEqualsVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/ModifierVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/CloneVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/TreeVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/visitor/HashCodeVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/imports/ImportDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/nodeTypes/NodeWithJavadocTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/nodeTypes/NodeWithModifiersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/nodeTypes/NodeWithVariablesTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/nodeTypes/NodeWithTraversableScopeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/nodeTypes/NodeWithOptionalScopeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/NodePositionTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/CompilationUnitTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/FindNodeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ast/observer/PropagatingAstObserverTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/ClassOrInterfaceDeclarationBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/NodeWithAnnotationsBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/FieldDeclarationBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/EnumDeclarationBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/NodeWithParametersBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/NodeWithThrownExceptionsBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/CompilationUnitBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/builders/NodeWithMembersBuildersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ProvidersTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/JavaTokenTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ParseErrorRecoveryTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/modules/ModuleDeclarationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/ParserConfigurationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/manual/BulkParseTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/CommentsInserterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/JavadocParserTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/ClassCreator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/MethodChanger_2.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/PrintingTheCompilationUnitToSystemOutputTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/CuPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/CreatingACompilationUnitFromScratch.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/removenode/ModifierVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/removenode/D.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/removenode/RemoveDeleteNodeFromAst.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/TestFileToken.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/ChangingMethodsFromAClassWithoutAVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/VisitingClassMethodsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/MethodChanger_1.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/ChangingMethodsFromAClassWithAVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/wiki_samples/MethodPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/javadoc/JavadocTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/javadoc/description/JavadocInlineTagTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/javadoc/JavadocExtractorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/TokenRangeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/remove/NodeRemovalTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/JavaParserTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/TestUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/SourceRootTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/CodeGenerationUtilsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/VisitorMapTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/PairTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/ParserCollectionStrategyTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/VisitorSetTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/VisitorListTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/SourceZipTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/utils/UtilsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/GeneratedJavaParserTokenManagerTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/version/Java10PostProcessorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/TestVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/PrettyPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/ConcreteSyntaxModelAcceptanceTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/DifferenceElementCalculatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/AbstractLexicalPreservingTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/LexicalDifferenceCalculatorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/ArrayCreationLevelTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/CompilationUnitTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/ConstructorDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/AnnotationDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/EnumConstantDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/MethodDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/StatementTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/EnumDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/InitializerDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/FieldDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/OperatorTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/ClassOrInterfaceDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/transformations/ast/body/AnnotationMemberDeclarationTransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/LexicalPreservingPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/lexicalpreservation/TransformationsTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/DotPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/YamlPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/ConcreteSyntaxModelTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/JsonPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/PrettyPrintVisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/printer/XmlPrinterTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/UnicodeEscapeProcessingProviderTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/PrettyPrintingTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/CommentParsingTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/TestUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/ComparingTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/VisitorTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/visitors/PositionTestVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/CommentParsingSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/PositionRangeSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/ManipulationSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/SharedSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/VisitorSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/PrettyPrintingSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/ComparingSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/ExistenceOfParentNodeVerifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/steps/ParsingSteps.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/ParsingTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/PositionRangeTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/ManipulationTest.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/src/test/java/com/github/javaparser/bdd/BasicJBehaveTest.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/target/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core-testing/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/javaparser-core-3.8.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-engine/5.3.1/junit-jupiter-engine-5.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apiguardian/apiguardian-api/1.0.0/apiguardian-api-1.0.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-engine/1.3.1/junit-platform-engine-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/platform/junit-platform-commons/1.3.1/junit-platform-commons-1.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/opentest4j/opentest4j/1.1.1/opentest4j-1.1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/junit/jupiter/junit-jupiter-api/5.3.1/junit-jupiter-api-5.3.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/jbehave/jbehave-core/4.3.5/jbehave-core-4.3.5.jar"); 
                 add("/home/maister/.m2/repository/junit/junit/4.12/junit-4.12.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/hamcrest/hamcrest-core/1.3/hamcrest-core-1.3.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/hamcrest/hamcrest-library/1.3/hamcrest-library-1.3.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/hamcrest/hamcrest-integration/1.3/hamcrest-integration-1.3.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/commons/commons-collections4/4.1/commons-collections4-4.1.jar"); 
                 add("/home/maister/.m2/repository/commons-io/commons-io/2.6/commons-io-2.6.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/commons/commons-lang3/3.7/commons-lang3-3.7.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/commons/commons-text/1.2/commons-text-1.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/codehaus/plexus/plexus-utils/3.1.0/plexus-utils-3.1.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/freemarker/freemarker/2.3.23/freemarker-2.3.23.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/thoughtworks/xstream/xstream/1.4.9/xstream-1.4.9.jar"); 
                 add("/home/maister/.m2/repository/xmlpull/xmlpull/1.1.3.1/xmlpull-1.1.3.1.jar"); 
                 add("/home/maister/.m2/repository/xpp3/xpp3_min/1.1.4c/xpp3_min-1.1.4c.jar"); 
                 add("/home/maister/.m2/repository/com/google/code/gson/gson/2.8.0/gson-2.8.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/github/valfirst/jbehave-junit-runner/2.2.0/jbehave-junit-runner-2.2.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/assertj/assertj-core/3.11.1/assertj-core-3.11.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/com/squareup/okhttp3/okhttp/3.11.0/okhttp-3.11.0.jar"); 
                 add("/home/maister/.m2/repository/com/squareup/okio/okio/1.14.0/okio-1.14.0.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_9_Java()

// %%
public void javaParser_10_Java() { 
     String fileOut = "_javaParser_10.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/SymbolResolver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/UnsolvedSymbolException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/Resolvable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedReferenceTypeDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedClassDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedEnumConstantDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedTypeParameterDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedParameterDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/HasAccessSpecifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/AssociableToAST.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedTypeDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedAnnotationMemberDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedValueDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedAnnotationDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedFieldDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedMethodLikeDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedInterfaceDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedMethodDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedTypeParametrizable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/declarations/ResolvedEnumDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedArrayType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedVoidType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedIntersectionType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedLambdaConstraintType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedPrimitiveType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedTypeVariable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedTypeTransformer.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedReferenceType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedUnionType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/ResolvedWildcard.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/parametrization/ResolvedTypeParametrized.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/parametrization/ResolvedTypeParameterValueProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/types/parametrization/ResolvedTypeParametersMap.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/MethodAmbiguityException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/resolution/MethodUsage.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/CommentsInserter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/AnnotationDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BaseNodeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/WildcardTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BooleanLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/TryStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SynchronizedStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ImportDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/VariableDeclarationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleUsesDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SimpleNameMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LocalClassDeclarationStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/MemberValuePairMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/EmptyStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LineCommentMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/VarTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/EnclosedExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ForEachStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/JavaParserMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ReferenceTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ThisExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/InstanceOfExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/WhileStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CharLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BlockStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LiteralStringValueExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CallableDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SuperExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/VoidTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NonEmptyProperty.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/MethodCallExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/UnaryExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ForStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/StatementMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SwitchEntryStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LabeledStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleRequiresDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/MethodDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/AnnotationMemberDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/EnumDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NormalAnnotationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/MarkerAnnotationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ClassOrInterfaceDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/FieldAccessExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/UnionTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ArrayAccessExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BlockCommentMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BreakStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleProvidesDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NullLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/UnknownTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ContinueStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/PrimitiveTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ReturnStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/TypeDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NameExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleExportsDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ParameterMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CastExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NameMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/TypeExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/OptionalProperty.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ClassOrInterfaceTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/DerivedProperty.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/DoubleLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BinaryExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/EnumConstantDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/InitializerDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ExplicitConstructorInvocationStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ArrayCreationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/AnnotationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/MethodReferenceExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/InternalProperty.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LambdaExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ExpressionStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/StringLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/TypeParameterMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/IntersectionTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SingleMemberAnnotationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ConditionalExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/IfStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CommentMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ClassExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ConstructorDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/AssertStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/UnparsableStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ArrayInitializerExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/VariableDeclaratorMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/AssignExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/PropertyMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/FieldDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/PackageDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ArrayTypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/BodyDeclarationMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CatchClauseMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/JavadocCommentMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ExpressionMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ReceiverParameterMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/TypeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/NodeMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LongLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/LiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ArrayCreationLevelMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/IntegerLiteralExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ThrowStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ObjectCreationExprMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/ModuleOpensDirectiveMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/DoStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/CompilationUnitMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/metamodel/SwitchStmtMetaModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/Problem.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/TokenRange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ParseProblemException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ParseStart.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ForEachStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/DoStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ExpressionStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ReturnStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ThrowStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/Statement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/WhileStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ContinueStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/LocalClassDeclarationStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/EmptyStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/BreakStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/SynchronizedStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/BlockStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/SwitchEntryStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/SwitchStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/AssertStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/IfStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/UnparsableStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/TryStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/LabeledStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/CatchClause.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ExplicitConstructorInvocationStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/stmt/ForStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/Generated.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java1_1Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java10Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/TreeVisitorValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java1_0Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java5Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/SimpleValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java1_2Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java6Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/SingleNodeTypeValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java9Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/VisitorValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/UnderscoreKeywordValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/VarValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/NoUnderscoresInIntegerLiteralsValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/ModifierValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/NoBinaryIntegerLiteralsValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/chunks/CommonValidators.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java7Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java1_3Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/ReservedKeywordValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java11Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Validators.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/TypedValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/NoProblemsValidator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java12Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/ProblemReporter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java8Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/validator/Java1_4Validator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/Modifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/comments/CommentsCollection.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/comments/LineComment.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/comments/JavadocComment.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/comments/BlockComment.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/comments/Comment.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/NodeList.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/ImportDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/CompilationUnit.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/PackageDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/DataKey.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleExportsDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleUsesDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleProvidesDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleRequiresDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/modules/ModuleOpensDirective.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/TypeExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/LiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/NullLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/IntegerLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/SingleMemberAnnotationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/BooleanLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/LiteralStringValueExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/DoubleLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ThisExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/VariableDeclarationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/LambdaExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ClassExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ArrayCreationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/AssignExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/UnaryExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/SuperExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ArrayAccessExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/InstanceOfExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ObjectCreationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/StringLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/NormalAnnotationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/FieldAccessExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/MarkerAnnotationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/SimpleName.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/MemberValuePair.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/BinaryExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/Name.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ConditionalExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/MethodCallExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/MethodReferenceExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/CharLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/CastExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/AnnotationExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/LongLiteralExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/ArrayInitializerExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/EnclosedExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/Expression.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/expr/NameExpr.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/AllFieldsConstructor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/ArrayCreationLevel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/ClassOrInterfaceType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/WildcardType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/TypeParameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/UnionType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/PrimitiveType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/UnknownType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/ReferenceType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/Type.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/VoidType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/VarType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/ArrayType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/type/IntersectionType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/BodyDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/InitializerDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/TypeDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/CallableDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/ConstructorDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/MethodDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/AnnotationDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/FieldDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/EnumDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/Parameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/ClassOrInterfaceDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/AnnotationMemberDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/EnumConstantDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/VariableDeclarator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/body/ReceiverParameter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/AccessSpecifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/Node.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/ModifierVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/HashCodeVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/VoidVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/GenericVisitorWithDefaults.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/VoidVisitorAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/GenericListVisitorAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/TreeVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/Visitable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/CloneVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/ObjectIdentityHashCodeVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/NoCommentEqualsVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/GenericVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/GenericVisitorAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/VoidVisitorWithDefaults.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/NoCommentHashCodeVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/ObjectIdentityEqualsVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/visitor/EqualsVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithAccessModifiers.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithFinalModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithAbstractModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithPublicModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithStaticModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithProtectedModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithPrivateModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/modifiers/NodeWithStrictfpModifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithArguments.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithOptionalLabel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithTraversableScope.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithImplements.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithJavadoc.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithThrownExceptions.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithParameters.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithScope.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithExtends.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithExpression.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithTypeArguments.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithBody.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithAnnotations.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithOptionalScope.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithBlockStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithCondition.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithMembers.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithType.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithRange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithConstructors.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithTokenRange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithSimpleName.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithTypeParameters.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithOptionalBlockStmt.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithVariables.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithName.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithStatements.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithIdentifier.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithDeclaration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/nodeTypes/NodeWithModifiers.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/observer/AstObserverAdapter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/observer/PropagatingAstObserver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/observer/AstObserver.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/observer/ObservableProperty.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ast/observer/Observable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/JavaToken.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/Providers.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/description/JavadocSnippet.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/description/JavadocInlineTag.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/description/JavadocDescriptionElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/description/JavadocDescription.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/Javadoc.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/javadoc/JavadocBlockTag.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/HasParentNode.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/TokenTypes.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/UnicodeEscapeProcessingProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ParserConfiguration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/Position.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/CollectionContext.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/ClassUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/Utils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/VisitorMap.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/SourceZip.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/CodeGenerationUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/SourceRoot.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/Pair.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/VisitorSet.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/SeparatedItemStringBuilder.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/ProjectRoot.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/Log.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/StringEscapeUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/CollectionStrategy.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/VisitorList.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/ParserCollectionStrategy.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/utils/PositionUtils.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/Range.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/JavadocParser.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/version/Java11PostProcessor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/version/Java12PostProcessor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/version/Java10PostProcessor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/version/PostProcessors.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/Printable.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/PrettyPrintVisitor.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/PrettyPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/DifferenceElementCalculator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/LexicalDifferenceCalculator.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/Kept.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/NodeText.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/Removed.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/TokenTextElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/Reshuffled.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/PhantomNodeLogic.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/Change.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/ListAdditionChange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/ListReplacementChange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/NoChange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/ListRemovalChange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/changes/PropertyChange.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/DifferenceElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/TextElementMatcher.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/Difference.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/TextElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/Added.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/ChildTextElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/LexicalPreservingPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/TextElementIteratorsFactory.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/RemovedGroup.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/lexicalpreservation/TextElementMatchers.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/PrettyPrinterConfiguration.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmUnindent.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmOrphanCommentsEnding.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmElement.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmConditional.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmIndent.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmSequence.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmComment.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/PrintingHelper.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmNone.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmMix.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmList.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmChar.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmAttribute.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmToken.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmString.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/concretesyntaxmodel/CsmSingleReference.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/YamlPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/ConcreteSyntaxModel.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/DotPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/XmlPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/JsonPrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/printer/SourcePrinter.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/ParseResult.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/java/com/github/javaparser/JavaParser.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/Provider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/StringProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/TokenMgrException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/ParseException.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/Token.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/GeneratedJavaParserConstants.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/GeneratedJavaParserTokenManager.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/SimpleCharStream.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/StreamProvider.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/javacc/com/github/javaparser/GeneratedJavaParser.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/javacc-support/com/github/javaparser/GeneratedJavaParserTokenManagerBase.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/javacc-support/com/github/javaparser/RangedList.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/javacc-support/com/github/javaparser/ModifierHolder.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/javacc-support/com/github/javaparser/GeneratedJavaParserBase.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/src/main/javacc-support/com/github/javaparser/TokenBase.java"); 
             add( 
                 "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/generated-sources/java-templates/com/github/javaparser/JavaParserBuild.java"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/7_javaparser/run-javaparser-java/javaparser-javaparser-parent-3.8.1/javaparser-core/target/classes"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JavaParserTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAVAFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue( 
             report 
                 .getBugInstance() 
                 .stream() 
                 .anyMatch( 
                     bugInstance -> { 
                       try { 
                         return Utils.containsAny( 
                             bugInstance.getClassName(), 
                             Utils.retrieveFullyQualifiedName(tempSource)); 
                       } catch (ExceptionHandler exceptionHandler) { 
                         exceptionHandler.printStackTrace(); 
                         return false; 
                       } 
                     })); 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
javaParser_10_Java()

// %%
public void generatedTest_velocityTools_Zero() { 
     String fileOut = "_GeneratedTestFile_0.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/GenericToolsTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/DisplayToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/AlternatorToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/CookieToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/XmlToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/JettyLogger.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/DisplayToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/FilteredLogChuteCommonsLog.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/ServletAdaptor.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/tools.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/ViewToolsTests.class"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/build/classes"); 
                 add( 
                     "/home/maister/.m2/repository/commons-beanutils/commons-beanutils/1.7.0/commons-beanutils-1.7.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-digester/commons-digester/1.8/commons-digester-1.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-chain/commons-chain/1.1/commons-chain-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-collections/commons-collections/3.2/commons-collections-3.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-lang/commons-lang/2.2/commons-lang-2.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-logging/commons-logging/1.1/commons-logging-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-validator/commons-validator/1.3.1/commons-validator-1.3.1.jar"); 
                 add("/home/maister/.m2/repository/dom4j/dom4j/1.1/dom4j-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/javax/servlet/servlet-api/2.3/servlet-api-2.3.jar"); 
                 add("/home/maister/.m2/repository/oro/oro/2.0.8/oro-2.0.8.jar"); 
                 add("/home/maister/.m2/repository/sslext/sslext/1.2-0/sslext-1.2-0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-core/1.3.8/struts-core-1.3.8.jar"); 
                 add("/home/maister/.m2/repository/antlr/antlr/2.7.2/antlr-2.7.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-taglib/1.3.8/struts-taglib-1.3.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-tiles/1.3.8/struts-tiles-1.3.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/velocity/velocity/1.6.2/velocity-1.6.2.jar"); 
                 add("/home/maister/.m2/repository/httpunit/httpunit/1.6.1/httpunit-1.6.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/jtidy/jtidy/4aug2000r7-dev/jtidy-4aug2000r7-dev.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jetty-embedded/6.0.1/jetty-embedded-6.0.1.jar"); 
                 add("/home/maister/.m2/repository/org/mortbay/jetty/jetty/6.0.1/jetty-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jetty-util/6.0.1/jetty-util-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/servlet-api-2.5/6.0.1/servlet-api-2.5-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jsp-api-2.1/6.0.1/jsp-api-2.1-6.0.1.jar"); 
                 add("/home/maister/.m2/repository/nekohtml/nekohtml/0.9.5/nekohtml-0.9.5.jar"); 
                 add("/home/maister/.m2/repository/rhino/js/1.6R5/js-1.6R5.jar"); 
                 add("/home/maister/.m2/repository/xerces/xercesImpl/2.8.1/xercesImpl-2.8.1.jar"); 
                 add("/home/maister/.m2/repository/xml-apis/xml-apis/1.3.03/xml-apis-1.3.03.jar"); 
                 add( 
                     "/home/maister/.m2/repository/xerces/xmlParserAPIs/2.6.2/xmlParserAPIs-2.6.2.jar"); 
                 add("/home/maister/.m2/repository/junit/junit/4.1/junit-4.1.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && VelocityTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.STREAM) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         /* 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue(report.getBugInstance().stream().anyMatch(bugInstance -> { 
             try { 
                 return Utils.containsAny(bugInstance.getClassName(), Utils.retrieveFullyQualifiedName(tempSource)); 
             } catch (ExceptionHandler exceptionHandler) { 
                 exceptionHandler.printStackTrace(); 
                 return false; 
             } 
         })); 
          */ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_velocityTools_Zero()

// %%
public void generatedTest_velocityTools_Zero() { 
     String fileOut = "_GeneratedTestFile_0.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/GenericToolsTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/DisplayToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/AlternatorToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/CookieToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/XmlToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/JettyLogger.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/ClassToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/DisplayToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/FilteredLogChuteCommonsLog.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LinkToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/generic/LoopToolTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/ServletAdaptor.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/whitebox/ConfigTests.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/tools.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes/org/apache/velocity/tools/test/blackbox/ViewToolsTests.class"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/dist/test-classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/6_velocitytools/run-velocitytools/velocity-tools-2.0/build/classes"); 
                 add( 
                     "/home/maister/.m2/repository/commons-beanutils/commons-beanutils/1.7.0/commons-beanutils-1.7.0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-digester/commons-digester/1.8/commons-digester-1.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-chain/commons-chain/1.1/commons-chain-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-collections/commons-collections/3.2/commons-collections-3.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-lang/commons-lang/2.2/commons-lang-2.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-logging/commons-logging/1.1/commons-logging-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/commons-validator/commons-validator/1.3.1/commons-validator-1.3.1.jar"); 
                 add("/home/maister/.m2/repository/dom4j/dom4j/1.1/dom4j-1.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/javax/servlet/servlet-api/2.3/servlet-api-2.3.jar"); 
                 add("/home/maister/.m2/repository/oro/oro/2.0.8/oro-2.0.8.jar"); 
                 add("/home/maister/.m2/repository/sslext/sslext/1.2-0/sslext-1.2-0.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-core/1.3.8/struts-core-1.3.8.jar"); 
                 add("/home/maister/.m2/repository/antlr/antlr/2.7.2/antlr-2.7.2.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-taglib/1.3.8/struts-taglib-1.3.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/struts/struts-tiles/1.3.8/struts-tiles-1.3.8.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/apache/velocity/velocity/1.6.2/velocity-1.6.2.jar"); 
                 add("/home/maister/.m2/repository/httpunit/httpunit/1.6.1/httpunit-1.6.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/jtidy/jtidy/4aug2000r7-dev/jtidy-4aug2000r7-dev.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jetty-embedded/6.0.1/jetty-embedded-6.0.1.jar"); 
                 add("/home/maister/.m2/repository/org/mortbay/jetty/jetty/6.0.1/jetty-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jetty-util/6.0.1/jetty-util-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/servlet-api-2.5/6.0.1/servlet-api-2.5-6.0.1.jar"); 
                 add( 
                     "/home/maister/.m2/repository/org/mortbay/jetty/jsp-api-2.1/6.0.1/jsp-api-2.1-6.0.1.jar"); 
                 add("/home/maister/.m2/repository/nekohtml/nekohtml/0.9.5/nekohtml-0.9.5.jar"); 
                 add("/home/maister/.m2/repository/rhino/js/1.6R5/js-1.6R5.jar"); 
                 add("/home/maister/.m2/repository/xerces/xercesImpl/2.8.1/xercesImpl-2.8.1.jar"); 
                 add("/home/maister/.m2/repository/xml-apis/xml-apis/1.3.03/xml-apis-1.3.03.jar"); 
                 add( 
                     "/home/maister/.m2/repository/xerces/xmlParserAPIs/2.6.2/xmlParserAPIs-2.6.2.jar"); 
                 add("/home/maister/.m2/repository/junit/junit/4.1/junit-4.1.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && VelocityTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.STREAM) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         /* 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue(report.getBugInstance().stream().anyMatch(bugInstance -> { 
             try { 
                 return Utils.containsAny(bugInstance.getClassName(), Utils.retrieveFullyQualifiedName(tempSource)); 
             } catch (ExceptionHandler exceptionHandler) { 
                 exceptionHandler.printStackTrace(); 
                 return false; 
             } 
         })); 
          */ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_velocityTools_Zero()

// %%
public void generatedTest_32() { 
     String fileOut = "_GeneratedTestFile_32.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/jacorb_imr/target/test-classes/org/jacorb/test/orbreinvoke/jacorb_imr/Server.class"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/jacorb_imr/target/test-classes"); 
                 //add( "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/jacorb_imr/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/core/target/jacorb-3.7.jar"); 
                 add("/home/maister/.m2/repository/org/slf4j/slf4j-api/1.7.6/slf4j-api-1.7.6.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/omgapi/target/jacorb-omgapi-3.7.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JacorbTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.STREAM) 
               + makeArg(argsIdentifier.VERYVERBOSE) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         /* 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue(report.getBugInstance().stream().anyMatch(bugInstance -> { 
             try { 
                 return Utils.containsAny(bugInstance.getClassName(), Utils.retrieveFullyQualifiedName(tempSource)); 
             } catch (ExceptionHandler exceptionHandler) { 
                 exceptionHandler.printStackTrace(); 
                 return false; 
             } 
         })); 
         */ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_32()

// %%
public void generatedTest_33() { 
     String fileOut = "_GeneratedTestFile_33.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/test-classes/org/jacorb/test/orbreinvoke/tao_imr/TwoPoaServer.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/test-classes/org/jacorb/test/orbreinvoke/tao_imr/OnePoaServer.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/test-classes/org/jacorb/test/orbreinvoke/tao_imr/MyCmdArgs.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/test-classes/org/jacorb/test/orbreinvoke/tao_imr/SimpleServer.class"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/test-classes"); 
                 //add("/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_imr/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/core/target/jacorb-3.7.jar"); 
                 add("/home/maister/.m2/repository/org/slf4j/slf4j-api/1.7.6/slf4j-api-1.7.6.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/omgapi/target/jacorb-omgapi-3.7.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JacorbTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.STREAM) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         /* 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue(report.getBugInstance().stream().anyMatch(bugInstance -> { 
             try { 
                 return Utils.containsAny(bugInstance.getClassName(), Utils.retrieveFullyQualifiedName(tempSource)); 
             } catch (ExceptionHandler exceptionHandler) { 
                 exceptionHandler.printStackTrace(); 
                 return false; 
             } 
         })); 
         */ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_33()

// %%
public void generatedTest_34() { 
     String fileOut = "_GeneratedTestFile_34.xml"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/test-classes/org/jacorb/test/orbreinvoke/tao_ns/Server.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/test-classes/org/jacorb/test/orbreinvoke/tao_ns/MyCmdArgs.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/test-classes/org/jacorb/test/orbreinvoke/tao_ns/ConnectNameService.class"); 
             add( 
                 "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/test-classes/org/jacorb/test/orbreinvoke/tao_ns/Client.class"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             ":", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/test-classes"); 
                 //add("/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/test/orbreinvoke/tao_ns/target/classes"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/core/target/jacorb-3.7.jar"); 
                 add("/home/maister/.m2/repository/org/slf4j/slf4j-api/1.7.6/slf4j-api-1.7.6.jar"); 
                 add( 
                     "/home/maister/.Projects/Bolo/5_jacorb/run-jacorb/jacorb-3.7/omgapi/target/jacorb-omgapi-3.7.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && JacorbTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.SOURCE, source) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.ScarfXML) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.STREAM) 
               + makeArg(argsIdentifier.NOEXIT); 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         AnalyzerReport report = AnalyzerReport.deserialize(new File(outputFile)); 
         /* 
         assertFalse(report.getBugInstance().isEmpty()); 
         assertTrue(report.getBugInstance().stream().anyMatch(bugInstance -> { 
             try { 
                 return Utils.containsAny(bugInstance.getClassName(), Utils.retrieveFullyQualifiedName(tempSource)); 
             } catch (ExceptionHandler exceptionHandler) { 
                 exceptionHandler.printStackTrace(); 
                 return false; 
             } 
         })); 
         */ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_34()

// %%
public void generatedTest_mercury() { 
     String fileOut = "_GeneratedTestFile4f584090-020e-44f1-83af-657e915c4d4c.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/com.mercury.wpad.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_mercury()

// %%
public void generatedTest_GingerMaster() { 
     String fileOut = "_GeneratedTestFile86efd42d-4641-441c-bab5-46be5b900b97.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/GingerMaster.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_GingerMaster()

// %%
public void generatedTest_gov() { 
     String fileOut = "_GeneratedTestFilec930c18c-ac0b-4263-8ab3-e5d96bbe3436.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add("/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/gov.ca.dmv.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_gov()

// %%
public void generatedTest_SandroRat() { 
     String fileOut = "_GeneratedTestFile62ce3c99-c25d-4f06-bc6f-82bb9172bb4c.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add("/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/SandroRat.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_SandroRat()

// %%
public void generatedTest_android() { 
     String fileOut = "_GeneratedTestFile4c4146ea-e4de-4844-a441-9e636950e33e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/2048-android-1.8/2048.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/2048-android-1.8/libs"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_android()

// %%
public void generatedTest_4f66121e_50f5_4e42_a876_905e10a8b5aa() { 
     String fileOut = "_GeneratedTestFile_4f66121e-50f5-4e42-a876-905e10a8b5aa.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/2048-android-master_1.95/2048.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_4f66121e_50f5_4e42_a876_905e10a8b5aa()

// %%
public void generatedTest_a79dfe40_1e97_4d47_acc6_f7e02fabae9a() { 
     String fileOut = "_GeneratedTestFile_a79dfe40-1e97-4d47-acc6-f7e02fabae9a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-admin-module-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a79dfe40_1e97_4d47_acc6_f7e02fabae9a()

// %%
public void generatedTest_c1d6353a_002b_4527_8536_374bcb13d7e5() { 
     String fileOut = "_GeneratedTestFile_c1d6353a-002b-4527-8536-374bcb13d7e5.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-common-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_c1d6353a_002b_4527_8536_374bcb13d7e5()

// %%
public void generatedTest_2c014ff5_a430_4814_a813_3b1a6c8180b8() { 
     String fileOut = "_GeneratedTestFile_2c014ff5-a430-4814-a813-3b1a6c8180b8.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-contentmanagement-module-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
   public void generatedTest_2c014ff5_a430_4814_a813_3b1a6c8180b8() { 
     String fileOut = "_GeneratedTestFile_2c014ff5-a430-4814-a813-3b1a6c8180b8.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-contentmanagement-module-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   } 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2c014ff5_a430_4814_a813_3b1a6c8180b8()

// %%
public void generatedTest_a73206a1_0345_4e7e_a795_0b1ec8de76a7() { 
     String fileOut = "_GeneratedTestFile_a73206a1-0345-4e7e-a795-0b1ec8de76a7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-framework-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a73206a1_0345_4e7e_a795_0b1ec8de76a7()

// %%
public void generatedTest_ebf00f49_2012_4fb9_b44c_d428ab00f6fe() { 
     String fileOut = "_GeneratedTestFile_ebf00f49-2012-4fb9-b44c-d428ab00f6fe.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-framework-web-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_ebf00f49_2012_4fb9_b44c_d428ab00f6fe()

// %%
public void generatedTest_5c42e0d6_2f20_449d_afa8_aaaa5e618538() { 
     String fileOut = "_GeneratedTestFile_5c42e0d6-2f20-449d-afa8-aaaa5e618538.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-open-admin-platform-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_5c42e0d6_2f20_449d_afa8_aaaa5e618538()

// %%
public void generatedTest_088d4f10_32d2_4a8c_88a9_f0c8b5202e20() { 
     String fileOut = "_GeneratedTestFile_088d4f10-32d2-4a8c-88a9-f0c8b5202e20.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-profile-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_088d4f10_32d2_4a8c_88a9_f0c8b5202e20()

// %%
public void generatedTest_e4024e68_0385_46a7_a430_b6e7ab1041b6() { 
     String fileOut = "_GeneratedTestFile_e4024e68-0385-46a7-a430-b6e7ab1041b6.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/broadleaf-profile-web-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_e4024e68_0385_46a7_a430_b6e7ab1041b6()

// %%
public void generatedTest_8cfabd39_3ecb_4ef2_88f1_42735bb2e3c7() { 
     String fileOut = "_GeneratedTestFile_8cfabd39-3ecb-4ef2-88f1-42735bb2e3c7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/BroadleafCommerce-broadleaf-3.0.3-GA/integration-3.0.3-GA.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_8cfabd39_3ecb_4ef2_88f1_42735bb2e3c7()

// %%
public void generatedTest_2e9b9df4_231e_4a04_9d62_ef9c0daf1546() { 
     String fileOut = "_GeneratedTestFile_2e9b9df4-231e-4a04-9d62-ef9c0daf1546.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/clojure-1.5.1/clojure-1.5.1.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2e9b9df4_231e_4a04_9d62_ef9c0daf1546()

// %%
public void generatedTest_ec888ec9_04f3_4334_bf92_5344ebb3c1eb() { 
     String fileOut = "_GeneratedTestFile_ec888ec9-04f3-4334-bf92-5344ebb3c1eb.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/clojure-1.5.1/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_ec888ec9_04f3_4334_bf92_5344ebb3c1eb()

// %%
public void generatedTest_26a80153_b5a0_4f80_b2de_da9f233aff20() { 
     String fileOut = "_GeneratedTestFile_26a80153-b5a0-4f80-b2de-da9f233aff20.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/TheElements-dev/bin/TheElements.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/TheElements-dev/libs/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_26a80153_b5a0_4f80_b2de_da9f233aff20()

// %%
public void generatedTest_a6dd1a8b_e932_4b9f_abce_f4f27c473b8b() { 
     String fileOut = "_GeneratedTestFile_a6dd1a8b-e932-4b9f-abce-f4f27c473b8b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/FallingSandpaper/bin/Wallpaper.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/FallingSandpaper/libs/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a6dd1a8b_e932_4b9f_abce_f4f27c473b8b()

// %%
public void generatedTest_1e3acc32_3e84_4f39_9f8d_b2db4e40b593() { 
     String fileOut = "_GeneratedTestFile_1e3acc32-3e84-4f39-9f8d-b2db4e40b593.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/felix.framework-4.2.1/org.apache.felix.framework-4.2.1.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1e3acc32_3e84_4f39_9f8d_b2db4e40b593()

// %%
public void generatedTest_0b864af0_2ae2_4963_bdfe_b9583a75537e() { 
     String fileOut = "_GeneratedTestFile_0b864af0-2ae2-4963-bdfe-b9583a75537e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/felix.framework-4.2.1/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_0b864af0_2ae2_4963_bdfe_b9583a75537e()

// %%
public void generatedTest_e2b17621_d592_4070_99c2_ee17c984152e() { 
     String fileOut = "_GeneratedTestFile_e2b17621-d592-4070-99c2-ee17c984152e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/guice-3.0.0/guice-3.0.0.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_e2b17621_d592_4070_99c2_ee17c984152e()

// %%
public void generatedTest_6a8f3b64_633f_46a7_a2a3_cc6fb4858753() { 
     String fileOut = "_GeneratedTestFile_6a8f3b64-633f-46a7-a2a3-cc6fb4858753.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-ant-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_6a8f3b64_633f_46a7_a2a3_cc6fb4858753()

// %%
public void generatedTest_0445ccdd_419a_4f12_9f4e_c8cecfd2c70e() { 
     String fileOut = "_GeneratedTestFile_0445ccdd-419a-4f12-9f4e-c8cecfd2c70e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-client-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_0445ccdd_419a_4f12_9f4e_c8cecfd2c70e()

// %%
public void generatedTest_be5656cb_6de2_476d_9430_768b2b7dae46() { 
     String fileOut = "_GeneratedTestFile_be5656cb-6de2-476d-9430-768b2b7dae46.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-core-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_be5656cb_6de2_476d_9430_768b2b7dae46()

// %%
public void generatedTest_28f4adb3_ef29_4e33_a3a7_3188847bfeda() { 
     String fileOut = "_GeneratedTestFile_28f4adb3-ef29-4e33-a3a7-3188847bfeda.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-examples-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_28f4adb3_ef29_4e33_a3a7_3188847bfeda()

// %%
public void generatedTest_adf9031d_3ec9_4174_8b38_35d0c03fa237() { 
     String fileOut = "_GeneratedTestFile_adf9031d-3ec9-4174-8b38-35d0c03fa237.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-minicluster-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_adf9031d_3ec9_4174_8b38_35d0c03fa237()

// %%
public void generatedTest_b19ed197_78b6_45dd_aff0_bf3a0dc2828a() { 
     String fileOut = "_GeneratedTestFile_b19ed197-78b6-45dd-aff0-bf3a0dc2828a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-test-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_b19ed197_78b6_45dd_aff0_bf3a0dc2828a()

// %%
public void generatedTest_36e0d4da_80bc_431d_8d2c_12cf98158acd() { 
     String fileOut = "_GeneratedTestFile_36e0d4da-80bc-431d-8d2c-12cf98158acd.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/hadoop-tools-1.1.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hadoop-1.1.2/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_36e0d4da_80bc_431d_8d2c_12cf98158acd()

// %%
public void generatedTest_f15b8dad_6c03_4b19_afe7_c5b6c987bfb6() { 
     String fileOut = "_GeneratedTestFile_f15b8dad-6c03-4b19-afe7-c5b6c987bfb6.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_f15b8dad_6c03_4b19_afe7_c5b6c987bfb6()

// %%
public void generatedTest_2fd19262_8e0f_4432_ae65_cac41c645d68() { 
     String fileOut = "_GeneratedTestFile_2fd19262-8e0f-4432-ae65-cac41c645d68.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-client-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2fd19262_8e0f_4432_ae65_cac41c645d68()

// %%
public void generatedTest_d38d8024_45e3_445d_86ea_536df8d7479a() { 
     String fileOut = "_GeneratedTestFile_d38d8024-45e3-445d-86ea-536df8d7479a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-cloud-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_d38d8024_45e3_445d_86ea_536df8d7479a()

// %%
public void generatedTest_63221dbd_c058_4689_82c2_2a959043ceb3() { 
     String fileOut = "_GeneratedTestFile_63221dbd-c058-4689-82c2-2a959043ceb3.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-hibernate3-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_63221dbd_c058_4689_82c2_2a959043ceb3()

// %%
public void generatedTest_feea7cd8_8cbc_4daa_a62e_906d58651511() { 
     String fileOut = "_GeneratedTestFile_feea7cd8-8cbc-4daa-a62e-906d58651511.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-hibernate4-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_feea7cd8_8cbc_4daa_a62e_906d58651511()

// %%
public void generatedTest_26305200_cff3_4c7b_9809_c9fcea9516fe() { 
     String fileOut = "_GeneratedTestFile_26305200-cff3-4c7b-9809-c9fcea9516fe.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-spring-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_26305200_cff3_4c7b_9809_c9fcea9516fe()

// %%
public void generatedTest_1c8d6e13_c4e2_45c4_9683_92cb48bc309c() { 
     String fileOut = "_GeneratedTestFile_1c8d6e13-c4e2-45c4-9683-92cb48bc309c.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/hazelcast-3.0.2/hazelcast-wm-3.0.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1c8d6e13_c4e2_45c4_9683_92cb48bc309c()

// %%
public void generatedTest_87c089fc_bbbc_4caa_8933_f0f328aa7ab7() { 
     String fileOut = "_GeneratedTestFile_87c089fc-bbbc-4caa-8933-f0f328aa7ab7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/Java-WebSocket-1.2.0/Java-WebSocket-1.0.0-SNAPSHOT.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_87c089fc_bbbc_4caa_8933_f0f328aa7ab7()

// %%
public void generatedTest_019c488c_bd32_4980_8553_1bb7c2533421() { 
     String fileOut = "_GeneratedTestFile_019c488c-bd32-4980-8553-1bb7c2533421.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/Java-WebSocket-1.2.0/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_019c488c_bd32_4980_8553_1bb7c2533421()

// %%
public void generatedTest_598c35c6_4acb_45fe_90f6_cb12a83c42d3() { 
     String fileOut = "_GeneratedTestFile_598c35c6-4acb-45fe-90f6-cb12a83c42d3.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/jenkins-1.534/jenkins-core-1.534.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_598c35c6_4acb_45fe_90f6_cb12a83c42d3()

// %%
public void generatedTest_bae6cda7_ca58_4cf9_a1b0_12b9ddb30edf() { 
     String fileOut = "_GeneratedTestFile_bae6cda7-ca58-4cf9-a1b0-12b9ddb30edf.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/JSPWiki-2.5.124/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/JSPWiki-2.5.124/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_bae6cda7_ca58_4cf9_a1b0_12b9ddb30edf()

// %%
public void generatedTest_568d7763_cae0_4e17_b76e_cf7cf7d27109() { 
     String fileOut = "_GeneratedTestFile_568d7763-cae0-4e17-b76e-cf7cf7d27109.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/JSPWiki-2.5.139/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/JSPWiki-2.5.139/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_568d7763_cae0_4e17_b76e_cf7cf7d27109()

// %%
public void generatedTest_f005dfe4_2bd1_4f92_b6ee_15679f80a800() { 
     String fileOut = "_GeneratedTestFile_f005dfe4-2bd1-4f92-b6ee-15679f80a800.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/junit-r4.12/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/junit-r4.12/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_f005dfe4_2bd1_4f92_b6ee_15679f80a800()

// %%
public void generatedTest_9c5d146f_e628_4328_bac1_75db7c54b2dc() { 
     String fileOut = "_GeneratedTestFile_9c5d146f-e628-4328-bac1-75db7c54b2dc.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/junit-r4.12/junit-4.12.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/junit-r4.12/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_9c5d146f_e628_4328_bac1_75db7c54b2dc()

// %%
public void generatedTest_500f69fd_3d14_4faa_8ddf_7f9f949d6269() { 
     String fileOut = "_GeneratedTestFile_500f69fd-3d14-4faa-8ddf-7f9f949d6269.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/mongo-java-driver-r2.11.3/mongo-java-driver-2.11.3.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/mongo-java-driver-r2.11.3/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_500f69fd_3d14_4faa_8ddf_7f9f949d6269()

// %%
public void generatedTest_cdf2475e_624b_462e_963b_87cee528cb98() { 
     String fileOut = "_GeneratedTestFile_cdf2475e-624b-462e-963b-87cee528cb98.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/mongo-java-driver-r2.11.3/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/mongo-java-driver-r2.11.3/lib/"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_cdf2475e_624b_462e_963b_87cee528cb98()

// %%
public void generatedTest_1c1b2a13_e0a2_48e0_a5ee_a0cc9c65deeb() { 
     String fileOut = "_GeneratedTestFile_1c1b2a13-e0a2-48e0-a5ee-a0cc9c65deeb.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-all-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1c1b2a13_e0a2_48e0_a5ee_a0cc9c65deeb()

// %%
public void generatedTest_1642e493_f255_4551_9a5a_3871c5bfcd97() { 
     String fileOut = "_GeneratedTestFile_1642e493-f255-4551-9a5a-3871c5bfcd97.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-buffer-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1642e493_f255_4551_9a5a_3871c5bfcd97()

// %%
public void generatedTest_5c417557_f27a_44ca_82c4_53b60d78dc09() { 
     String fileOut = "_GeneratedTestFile_5c417557-f27a-44ca-82c4-53b60d78dc09.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-codec-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_5c417557_f27a_44ca_82c4_53b60d78dc09()

// %%
public void generatedTest_55aac31e_aadd_4b83_95df_b2251d8638e3() { 
     String fileOut = "_GeneratedTestFile_55aac31e-aadd-4b83-95df-b2251d8638e3.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-codec-haproxy-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_55aac31e_aadd_4b83_95df_b2251d8638e3()

// %%
public void generatedTest_b3cf9c47_1693_45f7_a6ee_21496cadb1dd() { 
     String fileOut = "_GeneratedTestFile_b3cf9c47-1693-45f7-a6ee-21496cadb1dd.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-codec-http-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_b3cf9c47_1693_45f7_a6ee_21496cadb1dd()

// %%
public void generatedTest_18c9a27d_cba1_4247_a146_f3348f4c38ab() { 
     String fileOut = "_GeneratedTestFile_18c9a27d-cba1-4247-a146-f3348f4c38ab.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-codec-socks-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_18c9a27d_cba1_4247_a146_f3348f4c38ab()

// %%
public void generatedTest_ef2eae6b_ac9d_484e_a22b_42bb2da0818e() { 
     String fileOut = "_GeneratedTestFile_ef2eae6b-ac9d-484e-a22b-42bb2da0818e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-common-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_ef2eae6b_ac9d_484e_a22b_42bb2da0818e()

// %%
public void generatedTest_12f6b014_3050_4e0a_a20f_7d0a91978803() { 
     String fileOut = "_GeneratedTestFile_12f6b014-3050-4e0a-a20f-7d0a91978803.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-example-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_12f6b014_3050_4e0a_a20f_7d0a91978803()

// %%
public void generatedTest_ed851fa9_ddf8_4403_b692_e0182addea64() { 
     String fileOut = "_GeneratedTestFile_ed851fa9-ddf8-4403-b692-e0182addea64.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-handler-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_ed851fa9_ddf8_4403_b692_e0182addea64()

// %%
public void generatedTest_73dc2920_9d20_4e78_a899_47b1fd68b51b() { 
     String fileOut = "_GeneratedTestFile_73dc2920-9d20-4e78-a899-47b1fd68b51b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-microbench-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_73dc2920_9d20_4e78_a899_47b1fd68b51b()

// %%
public void generatedTest_41f27ba0_7631_43ef_9269_dcc2b71a8eab() { 
     String fileOut = "_GeneratedTestFile_41f27ba0-7631-43ef-9269-dcc2b71a8eab.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-testsuite-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_41f27ba0_7631_43ef_9269_dcc2b71a8eab()

// %%
public void generatedTest_f571b2d7_27e2_40a2_b8d9_8b968f68ccdc() { 
     String fileOut = "_GeneratedTestFile_f571b2d7-27e2-40a2-b8d9-8b968f68ccdc.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-testsuite-osgi-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_f571b2d7_27e2_40a2_b8d9_8b968f68ccdc()

// %%
public void generatedTest_3ab78c8a_0dde_4c1c_9bb2_a4180ec2efc2() { 
     String fileOut = "_GeneratedTestFile_3ab78c8a-0dde-4c1c-9bb2-a4180ec2efc2.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-transport-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_3ab78c8a_0dde_4c1c_9bb2_a4180ec2efc2()

// %%
public void generatedTest_65a9cdca_6381_4295_84ae_93e65b00977b() { 
     String fileOut = "_GeneratedTestFile_65a9cdca-6381-4295-84ae-93e65b00977b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-transport-rxtx-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_65a9cdca_6381_4295_84ae_93e65b00977b()

// %%
public void generatedTest_dfc627dc_f47f_4d1d_8740_afa86512e5b1() { 
     String fileOut = "_GeneratedTestFile_dfc627dc-f47f-4d1d-8740-afa86512e5b1.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-transportctp-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_dfc627dc_f47f_4d1d_8740_afa86512e5b1()

// %%
public void generatedTest_4884aa93_8c13_4417_8d6b_a242bd1f708d() { 
     String fileOut = "_GeneratedTestFile_4884aa93-8c13-4417-8d6b-a242bd1f708d.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/netty-transport-udt-4.0.34.Final.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_4884aa93_8c13_4417_8d6b_a242bd1f708d()

// %%
public void generatedTest_e1247b34_d67d_4590_80e3_e2b64f9e0bd6() { 
     String fileOut = "_GeneratedTestFile_e1247b34-d67d-4590-80e3-e2b64f9e0bd6.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/all/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_e1247b34_d67d_4590_80e3_e2b64f9e0bd6()

// %%
public void generatedTest_1cc33818_2c3b_4d26_9b59_3fbaff018dc8() { 
     String fileOut = "_GeneratedTestFile_1cc33818-2c3b-4d26-9b59-3fbaff018dc8.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/buffer/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1cc33818_2c3b_4d26_9b59_3fbaff018dc8()

// %%
public void generatedTest_fc66b858_b7a3_47c2_8d18_225da7d63ab3() { 
     String fileOut = "_GeneratedTestFile_fc66b858-b7a3-47c2-8d18-225da7d63ab3.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/codec/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_fc66b858_b7a3_47c2_8d18_225da7d63ab3()

// %%
public void generatedTest_df4e01a6_7ac0_41aa_ba35_a3d3f938048a() { 
     String fileOut = "_GeneratedTestFile_df4e01a6-7ac0-41aa-ba35-a3d3f938048a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/codec-haproxy/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_df4e01a6_7ac0_41aa_ba35_a3d3f938048a()

// %%
public void generatedTest_3259270f_0425_4a40_9fa4_e653a934b8f4() { 
     String fileOut = "_GeneratedTestFile_3259270f-0425-4a40-9fa4-e653a934b8f4.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/codec-http/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_3259270f_0425_4a40_9fa4_e653a934b8f4()

// %%
public void generatedTest_e9678546_95eb_4d35_bad8_b6f0adedffe9() { 
     String fileOut = "_GeneratedTestFile_e9678546-95eb-4d35-bad8-b6f0adedffe9.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/codecocks/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_e9678546_95eb_4d35_bad8_b6f0adedffe9()

// %%
public void generatedTest_c1b5786b_4f50_425c_bef3_d8ab3bfe31d5() { 
     String fileOut = "_GeneratedTestFile_c1b5786b-4f50-425c-bef3-d8ab3bfe31d5.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/common/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_c1b5786b_4f50_425c_bef3_d8ab3bfe31d5()

// %%
public void generatedTest_30c41563_04fd_41d7_9884_64d84ce5da9c() { 
     String fileOut = "_GeneratedTestFile_30c41563-04fd-41d7-9884-64d84ce5da9c.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/example/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_30c41563_04fd_41d7_9884_64d84ce5da9c()

// %%
public void generatedTest_e7562938_91e9_47ba_96d6_0063bfa61c01() { 
     String fileOut = "_GeneratedTestFile_e7562938-91e9-47ba-96d6-0063bfa61c01.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/handler/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_e7562938_91e9_47ba_96d6_0063bfa61c01()

// %%
public void generatedTest_c407ad27_c5a7_4eab_bb6e_d268789b7e4f() { 
     String fileOut = "_GeneratedTestFile_c407ad27-c5a7-4eab-bb6e-d268789b7e4f.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/microbench/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_c407ad27_c5a7_4eab_bb6e_d268789b7e4f()

// %%
public void generatedTest_9ebfe7e6_1c5e_44d4_985d_a18ce13cafaf() { 
     String fileOut = "_GeneratedTestFile_9ebfe7e6-1c5e-44d4-985d-a18ce13cafaf.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/tarball/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_9ebfe7e6_1c5e_44d4_985d_a18ce13cafaf()

// %%
public void generatedTest_0452c134_c0bd_4515_9f64_5e33304cf66f() { 
     String fileOut = "_GeneratedTestFile_0452c134-c0bd-4515-9f64-5e33304cf66f.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/testsuite/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_0452c134_c0bd_4515_9f64_5e33304cf66f()

// %%
public void generatedTest_6e697c52_71de_4279_90e3_ae9d6fb817d6() { 
     String fileOut = "_GeneratedTestFile_6e697c52-71de-4279-90e3-ae9d6fb817d6.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_6e697c52_71de_4279_90e3_ae9d6fb817d6()

// %%
public void generatedTest_a310a989_0d2f_4c92_a966_4ac95c0ebc86() { 
     String fileOut = "_GeneratedTestFile_a310a989-0d2f-4c92-a966-4ac95c0ebc86.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/transport/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a310a989_0d2f_4c92_a966_4ac95c0ebc86()

// %%
public void generatedTest_89e31905_0bdb_4732_b9aa_6291c59beaef() { 
     String fileOut = "_GeneratedTestFile_89e31905-0bdb-4732-b9aa-6291c59beaef.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/transport-rxtx/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_89e31905_0bdb_4732_b9aa_6291c59beaef()

// %%
public void generatedTest_0401ae66_4876_4af4_baac_9d7992728fc8() { 
     String fileOut = "_GeneratedTestFile_0401ae66-4876-4af4-baac-9d7992728fc8.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/transportctp/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_0401ae66_4876_4af4_baac_9d7992728fc8()

// %%
public void generatedTest_a46e975e_7025_4339_a101_ee24b649784e() { 
     String fileOut = "_GeneratedTestFile_a46e975e-7025-4339-a101-ee24b649784e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/netty-netty-4.0.34.Final/transport-udt/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a46e975e_7025_4339_a101_ee24b649784e()

// %%
public void generatedTest_237b902b_a661_45f0_930c_5ef446e88521() { 
     String fileOut = "_GeneratedTestFile_237b902b-a661-45f0-930c-5ef446e88521.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/owasp-1-liner-master/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_237b902b_a661_45f0_930c_5ef446e88521()

// %%
public void generatedTest_17f4bd86_5ee3_4a74_ae37_f2f587e89d11() { 
     String fileOut = "_GeneratedTestFile_17f4bd86-5ee3-4a74-ae37-f2f587e89d11.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/owaspantisamy-d4575adf1985/antisamy-1.5.4-SNAPSHOT.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_17f4bd86_5ee3_4a74_ae37_f2f587e89d11()

// %%
public void generatedTest_84dbe69a_2da4_405f_9f63_885a6fc59196() { 
     String fileOut = "_GeneratedTestFile_84dbe69a-2da4-405f-9f63-885a6fc59196.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/owaspantisamy-d4575adf1985/antisamy/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_84dbe69a_2da4_405f_9f63_885a6fc59196()

// %%
public void generatedTest_9b016fec_6c49_4b07_a900_ccf69bae6d09() { 
     String fileOut = "_GeneratedTestFile_9b016fec-6c49-4b07-a900-ccf69bae6d09.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/owasp-esapi-swingset-interactive/SwingSet/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_9b016fec_6c49_4b07_a900_ccf69bae6d09()

// %%
public void generatedTest_b4ba3837_384c_4c93_8b9f_e6ece19458c7() { 
     String fileOut = "_GeneratedTestFile_b4ba3837-384c-4c93-8b9f-e6ece19458c7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/pegasus-4.2.2/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_b4ba3837_384c_4c93_8b9f_e6ece19458c7()

// %%
public void generatedTest_a438226e_5169_4b60_aaac_d5fb18f179c9() { 
     String fileOut = "_GeneratedTestFile_a438226e-5169-4b60-aaac-d5fb18f179c9.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/pegasus-4.2.2/pegasus.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/pegasus-4.2.2/pegasus.jar"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a438226e_5169_4b60_aaac_d5fb18f179c9()

// %%
public void generatedTest_2b3140e4_55a7_4e2b_9875_618a7809fda2() { 
     String fileOut = "_GeneratedTestFile_2b3140e4-55a7-4e2b-9875-618a7809fda2.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/SampleApplication/bin/SampleApplication.apk"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.APK) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2b3140e4_55a7_4e2b_9875_618a7809fda2()

// %%
public void generatedTest_a2ebe46e_9200_4756_86a4_84a42530fe29() { 
     String fileOut = "_GeneratedTestFile_a2ebe46e-9200-4756-86a4-84a42530fe29.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/scarab-1.0.22-RC1/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a2ebe46e_9200_4756_86a4_84a42530fe29()

// %%
public void generatedTest_575dd5fb_00f4_4ee9_989f_17b60ee0d6e8() { 
     String fileOut = "_GeneratedTestFile_575dd5fb-00f4-4ee9-989f-17b60ee0d6e8.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-all-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_575dd5fb_00f4_4ee9_989f_17b60ee0d6e8()

// %%
public void generatedTest_c5034cec_e541_45ea_9a80_88f0808a593d() { 
     String fileOut = "_GeneratedTestFile_c5034cec-e541-45ea-9a80-88f0808a593d.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-berkeleyje-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_c5034cec_e541_45ea_9a80_88f0808a593d()

// %%
public void generatedTest_344d7d81_eec5_49fc_b6b1_277985c9a9f6() { 
     String fileOut = "_GeneratedTestFile_344d7d81-eec5-49fc-b6b1-277985c9a9f6.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-cassandra-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_344d7d81_eec5_49fc_b6b1_277985c9a9f6()

// %%
public void generatedTest_17d2b41a_ccd8_4b65_924c_3f1a39638b21() { 
     String fileOut = "_GeneratedTestFile_17d2b41a-ccd8-4b65-924c-3f1a39638b21.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-core-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_17d2b41a_ccd8_4b65_924c_3f1a39638b21()

// %%
public void generatedTest_f79919e8_870c_4c57_892c_9d74d05534d7() { 
     String fileOut = "_GeneratedTestFile_f79919e8-870c-4c57-892c-9d74d05534d7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-es-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_f79919e8_870c_4c57_892c_9d74d05534d7()

// %%
public void generatedTest_521a30f2_7c6b_4d9b_9f8d_700fc8e14f59() { 
     String fileOut = "_GeneratedTestFile_521a30f2-7c6b-4d9b-9f8d-700fc8e14f59.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-hbase-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_521a30f2_7c6b_4d9b_9f8d_700fc8e14f59()

// %%
public void generatedTest_fda0f3d2_17dd_45af_a975_4f5a45763365() { 
     String fileOut = "_GeneratedTestFile_fda0f3d2-17dd-45af-a975-4f5a45763365.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-lucene-0.3.2.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_fda0f3d2_17dd_45af_a975_4f5a45763365()

// %%
public void generatedTest_dcb4293c_3322_42e0_8f92_429787d4b336() { 
     String fileOut = "_GeneratedTestFile_dcb4293c-3322-42e0-8f92-429787d4b336.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-all/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_dcb4293c_3322_42e0_8f92_429787d4b336()

// %%
public void generatedTest_71b37f52_a26a_4a8b_a49d_f5871128ac4a() { 
     String fileOut = "_GeneratedTestFile_71b37f52-a26a-4a8b-a49d-f5871128ac4a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-berkeleyje/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_71b37f52_a26a_4a8b_a49d_f5871128ac4a()

// %%
public void generatedTest_955b1639_12de_4b0d_8709_d40199a7ab30() { 
     String fileOut = "_GeneratedTestFile_955b1639-12de-4b0d-8709-d40199a7ab30.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-cassandra/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_955b1639_12de_4b0d_8709_d40199a7ab30()

// %%
public void generatedTest_72d00b8d_bd1d_4a59_980f_6ddb247c1114() { 
     String fileOut = "_GeneratedTestFile_72d00b8d-bd1d-4a59-980f-6ddb247c1114.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-core/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_72d00b8d_bd1d_4a59_980f_6ddb247c1114()

// %%
public void generatedTest_d75c9bc1_54a5_42a5_b71c_e581e267b886() { 
     String fileOut = "_GeneratedTestFile_d75c9bc1-54a5-42a5-b71c-e581e267b886.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-es/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_d75c9bc1_54a5_42a5_b71c_e581e267b886()

// %%
public void generatedTest_2a0064e1_507c_442b_a258_ac8d1508d330() { 
     String fileOut = "_GeneratedTestFile_2a0064e1-507c-442b-a258-ac8d1508d330.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-hbase/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2a0064e1_507c_442b_a258_ac8d1508d330()

// %%
public void generatedTest_f8034725_f5dd_45ad_ba62_5c6fc9011d85() { 
     String fileOut = "_GeneratedTestFile_f8034725-f5dd-45ad-ba62-5c6fc9011d85.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/titan-0.3.2/titan-lucene/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_f8034725_f5dd_45ad_ba62_5c6fc9011d85()

// %%
public void generatedTest_165b4ed9_bebf_4b64_a635_e9618ed19e89() { 
     String fileOut = "_GeneratedTestFile_165b4ed9-bebf-4b64-a635-e9618ed19e89.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/tomcat-ajp-5.5.23/tomcat-ajp-5.5.23.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_165b4ed9_bebf_4b64_a635_e9618ed19e89()

// %%
public void generatedTest_6e12ea06_473f_4353_83d6_4c218b07924b() { 
     String fileOut = "_GeneratedTestFile_6e12ea06-473f-4353-83d6-4c218b07924b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/tomcat-coyote-7.0.27/tomcat-coyote-7.0.27.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_6e12ea06_473f_4353_83d6_4c218b07924b()

// %%
public void generatedTest_dee25128_ce57_4a4e_aa92_06c3ee5a2d7f() { 
     String fileOut = "_GeneratedTestFile_dee25128-ce57-4a4e-aa92-06c3ee5a2d7f.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/velocity-tools-2.0/velocity-tools-2.0.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_dee25128_ce57_4a4e_aa92_06c3ee5a2d7f()

// %%
public void generatedTest_ebdcd6e7_33b4_436c_becd_a8a5f940568b() { 
     String fileOut = "_GeneratedTestFile_ebdcd6e7-33b4-436c-becd-a8a5f940568b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/velocity-tools-2.0/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_ebdcd6e7_33b4_436c_becd_a8a5f940568b()

// %%
public void generatedTest_7b783286_70ba_406e_b9a6_6d9f776f339e() { 
     String fileOut = "_GeneratedTestFile_7b783286-70ba-406e-b9a6-6d9f776f339e.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/voldemort-1.4.0/voldemort-1.4.0.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_7b783286_70ba_406e_b9a6_6d9f776f339e()

// %%
public void generatedTest_3e71085f_d144_4cb5_b3f2_925744187b63() { 
     String fileOut = "_GeneratedTestFile_3e71085f-d144-4cb5-b3f2-925744187b63.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/voldemort-1.4.0/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/voldemort-1.4.0/lib"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_3e71085f_d144_4cb5_b3f2_925744187b63()

// %%
public void generatedTest_cfcdcecb_51c8_439e_aefa_d34b802be6a7() { 
     String fileOut = "_GeneratedTestFile_cfcdcecb-51c8-439e-aefa-d34b802be6a7.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/wavsep-v1.2rc-eclipse-archive/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     String tempDependency = 
         Utils.join( 
             " ", 
             new ArrayList<String>() { 
               { 
                 add( 
                     "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/wavsep-v1.2rc-eclipse-archive/lib"); 
               } 
             }); 
     String dependency = Utils.join(" ", tempDependency); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.DEPENDENCY, dependency) 
               + //1 + 
               makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_cfcdcecb_51c8_439e_aefa_d34b802be6a7()

// %%
public void generatedTest_cb41f97f_5a53_4ae8_b386_c96a4ffab48d() { 
     String fileOut = "_GeneratedTestFile_cb41f97f-5a53-4ae8-b386-c96a4ffab48d.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/webgoat-5.4/WebGoat-6.0.1-war-exec.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_cb41f97f_5a53_4ae8_b386_c96a4ffab48d()

// %%
public void generatedTest_6384ca90_6fad_4278_96b7_509611aeb38b() { 
     String fileOut = "_GeneratedTestFile_6384ca90-6fad-4278-96b7-509611aeb38b.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/webgoat-5.4/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_6384ca90_6fad_4278_96b7_509611aeb38b()

// %%
public void generatedTest_820e0979_f9b0_4999_8aaa_64ba1e2102ba() { 
     String fileOut = "_GeneratedTestFile_820e0979-f9b0-4999-8aaa-64ba1e2102ba.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/gradle-modular-1.0/client/build/libs/client-1.0.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_820e0979_f9b0_4999_8aaa_64ba1e2102ba()

// %%
public void generatedTest_a658b070_f10e_40b5_8496_90a78a53b7e4() { 
     String fileOut = "_GeneratedTestFile_a658b070-f10e-40b5-8496-90a78a53b7e4.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/gradle-modular-1.0/server/build/libs/server-1.0.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a658b070_f10e_40b5_8496_90a78a53b7e4()

// %%
public void generatedTest_1b5272da_0170_4a96_84f3_031caafb9d85() { 
     String fileOut = "_GeneratedTestFile_1b5272da-0170-4a96-84f3-031caafb9d85.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/gradle-modular-1.0/server/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_1b5272da_0170_4a96_84f3_031caafb9d85()

// %%
public void generatedTest_a29088d4_b3bd_4f58_a710_af4c3aa97574() { 
     String fileOut = "_GeneratedTestFile_a29088d4-b3bd-4f58-a710-af4c3aa97574.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/gradle-modular-1.0/client/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_a29088d4_b3bd_4f58_a710_af4c3aa97574()

// %%
public void generatedTest_4789be96_a2fe_4ada_bfd4_e9ae7d804c90() { 
     String fileOut = "_GeneratedTestFile_4789be96-a2fe-4ada-bfd4-e9ae7d804c90.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/Benchmark-1.1/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_4789be96_a2fe_4ada_bfd4_e9ae7d804c90()

// %%
public void generatedTest_2f7686d7_44a2_46b5_b829_9f097111a12a() { 
     String fileOut = "_GeneratedTestFile_2f7686d7-44a2-46b5-b829-9f097111a12a.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/Benchmark-1.2beta/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2f7686d7_44a2_46b5_b829_9f097111a12a()

// %%
public void generatedTest_2eed8e21_46b7_49c7_bd9a_a60fa95fa646() { 
     String fileOut = "_GeneratedTestFile_2eed8e21-46b7-49c7-bd9a-a60fa95fa646.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/PlagiarismDetector-f8c6f9e8bb/PlagiarismDetector.jar"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.JAR) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_2eed8e21_46b7_49c7_bd9a_a60fa95fa646()

// %%
public void generatedTest_378e6024_f059_47ed_b9d3_625c14756562() { 
     String fileOut = "_GeneratedTestFile_378e6024-f059-47ed-b9d3-625c14756562.json"; 
     new File(fileOut).delete(); 
  
     ArrayList<String> tempSource = 
         new ArrayList<String>() { 
           { 
             add( 
                 "/home/maister/.Projects/Bolo/Mir-Swamp-Packages/20200429/Packages/PlagiarismDetector-f8c6f9e8bb/input.in"); 
           } 
         }; 
     String source = Utils.join(" ", tempSource); 
  
     if (isLinux && SWAMPGeneratedTests) { 
  
       String args = 
           makeArg(argsIdentifier.FORMAT, EngineType.CLASSFILES) 
               + makeArg(argsIdentifier.OUT, fileOut) 
               + makeArg(argsIdentifier.NOEXIT) 
               + makeArg(argsIdentifier.PRETTY) 
               + makeArg(argsIdentifier.FORMATOUT, Listing.Default) 
               + makeArg(argsIdentifier.SOURCE, source); //1 
  
       try { 
         String outputFile = captureNewFileOutViaStdOut(args.split(" ")); 
  
         Report report = Report.deserialize(new File(outputFile)); 
         //assertFalse(report.getIssues().isEmpty()); 
         /*assertTrue 
         report 
             .getIssues() 
             .stream() 
             .anyMatch( 
                 bugInstance -> { 
                   try { 
                     return Utils.containsAny( 
                         bugInstance.getFullPath(), 
                         Utils.retrieveFullyQualifiedNameFileSep(tempSource)); 
                   } catch (ExceptionHandler e) { 
                     assertNull(e); 
                     e.printStackTrace(); 
                   } 
                   return false; 
                 }));*/ 
  
       } catch (Exception e) { 
         e.printStackTrace(); 
         assertNull(e); 
       } 
     } 
   }

// %%
generatedTest_378e6024_f059_47ed_b9d3_625c14756562()
